# %%
import networkx as nx
import operator
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.lines import Line2D
import matplotlib.path as mpath
G=nx.Graph()

#read edges from csv file
file_edges=open("4-edges.csv", "r")
while(1):
    content = file_edges.readline()
    if content == "":
        break
    line = content.split(",")
    #print(line[0], line[1], line[2])
    G.add_edge(line[0], line[1]) #add weighted edges to Graph

number_of_nodes = G.number_of_nodes()

av_degree = (2*G.number_of_edges())/number_of_nodes # av_degree = 2*E/N ignoring this is a weighted graph


#CENTRALITY

dg_centrality = nx.degree_centrality(G)
#for k,v in sorted(dg_centrality.items(), key=lambda p:p[1], reverse=True):
    #print(k,v)
    
ev_centrality = nx.eigenvector_centrality_numpy(G)
#for k,v in sorted(ev_centrality.items(), key=lambda p:p[1], reverse=True):
    #print(k,v)
    
#bn_centrality = nx.betweenness_centrality(G)

x=list(ev_centrality.values())
#x=list(bn_centrality.values())
y=list(dg_centrality.values())
#y=list(bn_centrality.values())

points = np.column_stack([x, y])
verts = np.array([[0.033, 0.033, 0.047, 0.047, ], [max(y)+0.05, 0.28, 0.47, max(y)+0.05]]).T
path = mpath.Path(verts)
points_inside = points[path.contains_points(points)]

plt.figure()
plt.autoscale(enable=True, axis='y', tight=True)
plt.autoscale(enable=True, axis='x', tight=False)
plt.xticks(np.arange(min(x), max(x)+0.005, 0.005))
plt.yticks(np.arange(min(y), max(y)+0.05, 0.05))
plt.rcParams['xtick.top'] = True
plt.rcParams['ytick.right'] = True

#plt.xlabel("Betweeness Centrality")
plt.xlabel("EigenVector Centrality")
plt.ylabel("Degree Centrality")
#plt.ylabel("Betweeness Centrality")


plt.plot(x, y, color='b', marker='o', linestyle="None", markersize=3)

plt.plot([0.033, 0.033, 0.047, 0.047, ], [max(y)+0.05, 0.28, 0.47, max(y)+0.05], color='r', linewidth=1, linestyle='--')
plt.scatter(points_inside[:,0], points_inside[:,1], c='r', s=25)


#plt.savefig('evVSdg.png')
plt.savefig('evVSdg_redzoom.png')

# %%
#Individual Histogram of Eigenvector Centrality
x=list(ev_centrality.values())

plt.figure()
plt.hist(list(ev_centrality.values()), bins=9)
plt.xlabel("Eigenvector Centrality")
plt.ylabel("Number of nodes")
plt.xticks(np.arange(min(x), max(x)+0.005, 0.005))
# Out:
# ([<matplotlib.axis.XTick at 0x7ff14a6e52e8>,
# ...
#  <a list of 10 Text xticklabel objects>)

# %%
#Individual Histogram of Degree Centrality
x=list(dg_centrality.values())

plt.figure()
plt.hist(list(dg_centrality.values()), bins=11)
plt.xlabel("Degree Centrality")
plt.ylabel("Number of nodes")
plt.xticks(np.arange(min(x), max(x)+0.05, 0.05))
# Out:
# ([<matplotlib.axis.XTick at 0x7ff14a45a6d8>,
# ...
#  <a list of 13 Text xticklabel objects>)

# %%
#Individual Histogram of Betweeness Centrality

# %%
#Save g to the file my_graph.graphml in graphml format
#prettyprint will make it nice for a human to read
nx.write_graphml(G,"my_graph.graphml",prettyprint=True)

#Layout G with the Fruchterman-Reingold force-directed
#algorithm and save the result to my_graph.png
#with_labels will label each node with its id

nx.spring_layout(G, scale=3)
nx.draw_spring(G,with_labels=True)
plt.savefig("my_graph.png")
plt.clf() #Clear plot

# %%
Report:
"""
From the four centrality measures learned (and their variations) we choose to apply the degree centrality and 
eigenvector centrality. We decided that the betweenness centrality and closeness centrality would be less 
important as they measure the importance of the nodes regarding their own distance to other nodes, or the 
presence in the shortest path between two other nodes. This is not relevant in our context because if two 
nodes are separated from more than 1 edge (meaning they are not directly connected) then they have no 
subscribers in common and since the number of people in common may be high or low, then the distance is not a 
good measure of how proportionally related two channels are.

Nonetheless, as a comparison we looked at «Analysis of the YouTube Channel Recommendation Network» by Ian 
torres and acob Conrad Trinidad. They considered the nodes to be the videos and a node would point to other 
if the former recommended the visualization of the latter. Eventhough the graph is completely different from 
ours, the context is the same. In those conditions, the measure out-degree and closeness centrality were 
concluded to be of low importance since in that context the number of videos that one channel could recommend
is limited by YouTube, and therefore those measures are highly limited. Considering the channels that each 
video belonged to, they concluded that betweeness centrality was a good measure to identify the most popular
channels (known à priori) and therefore we felt motivated to also try that measure. 

Our results regarding eigenvector centrality and degree centrality showed higher heterogeneity using the ??? 
centrality, which may indicate that... 

Plotting the two measures against each other we reach a lower/higher?? number of nodes with both high values.
These nodes are ...

"""
